# %% [markdown]
# <a href="https://colab.research.google.com/github/ashrafsohail42003/Training-project/blob/main/Feature_Engineering_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

# %%
path = '/content/drive/MyDrive/AXSOSACADEMY/03-DataEnrichment/Week09/Data/bikeshare_train - bikeshare_train.csv'
df = pd.read_csv(path)
df.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 0:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 1:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 2:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 3:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 4:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
df = df.drop(columns =["casual", "registered"])

# %%
df["datetime"] = pd.to_datetime(df["datetime"])
df["month_name"] = df["datetime"].dt.month_name().astype("object")
df["day_name"] = df["datetime"].dt.day_name().astype("object")
df["hour"] = df["datetime"].dt.hour.astype("object")
df = df.drop(columns=["datetime", "season"])
df.head()
# Out:
#    holiday  workingday  weather  temp   atemp  humidity  windspeed  count  \
# 0        0           0        1  9.84  14.395        81        0.0     16
# 1        0           0        1  9.02  13.635        80        0.0     40
# 2        0           0        1  9.02  13.635        80        0.0     32
# 3        0           0        1  9.84  14.395        75        0.0     13
# 4        0           0        1  9.84  14.395        75        0.0      1
#
#   month_name  day_name hour
# 0    January  Saturday    0
# 1    January  Saturday    1
# 2    January  Saturday    2
# 3    January  Saturday    3
# 4    January  Saturday    4

# %%
df["temp"] = df["temp"].apply(lambda x: (x * 9/5) + 32)
df["atemp"] = df["atemp"].apply(lambda x: (x * 9/5) + 32)
df[["temp", "atemp"]].head()
# Out:
#      temp   atemp
# 0  49.712  57.911
# 1  48.236  56.543
# 2  48.236  56.543
# 3  49.712  57.911
# 4  49.712  57.911

# %%
df["temp_variance"] = df["temp"] - df["atemp"]

df = df.drop(columns=["atemp"])

df.head()
# Out:
#    holiday  workingday  weather    temp  humidity  windspeed  count  \
# 0        0           0        1  49.712        81        0.0     16
# 1        0           0        1  48.236        80        0.0     40
# 2        0           0        1  48.236        80        0.0     32
# 3        0           0        1  49.712        75        0.0     13
# 4        0           0        1  49.712        75        0.0      1
#
#   month_name  day_name hour  temp_variance
# 0    January  Saturday    0         -8.199
# 1    January  Saturday    1         -8.307
# 2    January  Saturday    2         -8.307
# 3    January  Saturday    3         -8.199
# 4    January  Saturday    4         -8.199
